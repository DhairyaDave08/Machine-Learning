# %% [markdown]
# # **Predict Using Pipelines**
# -Dhairya Dave

# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('/content/drive/MyDrive/Machine Learning/Python codes/Python Libraries Basics/pipe.pkl','rb'))

# %%
test_input2 = np.array([2, 'female', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
